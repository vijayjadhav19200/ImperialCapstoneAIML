# %%
import numpy as np
import math
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold

# =========================================================
# WEEK 9 FUNCTION 6 — SCALING/EMERGENT-AWARE BO (COST-ROBUST)
# Core upgrades vs Week 8:
#  - Successive Halving hyperparam tuning (cheaper, more robust)
#  - Scaling-law aware exploration decay (xi decreases with n)
#  - Emergent-behaviour hedge: small % picks by uncertainty/random
#  - qEI (MC) over ensemble (reduces brittle EI overconfidence)
#  - Diversity penalty to avoid near-duplicates / local traps
#  - Output: x_next printed in <= 6 decimals
# =========================================================

# -----------------------------
# 1) Data (as provided)
# -----------------------------
X_raw = np.array([
 [0.7281861, 0.15469257, 0.73255167, 0.69399651, 0.05640131],
 [0.24238435, 0.84409997, 0.5778091, 0.67902128, 0.50195289],
 [0.72952261, 0.7481062, 0.67977464, 0.35655228, 0.67105368],
 [0.77062024, 0.11440374, 0.04677993, 0.64832428, 0.27354905],
 [0.6188123, 0.33180214, 0.18728787, 0.75623847, 0.3288348],
 [0.78495809, 0.91068235, 0.7081201, 0.95922543, 0.0049115],
 [0.14511079, 0.8966846, 0.89632223, 0.72627154, 0.23627199],
 [0.94506907, 0.28845905, 0.97880576, 0.96165559, 0.59801594],
 [0.12572016, 0.86272469, 0.02854433, 0.24660527, 0.75120624],
 [0.75759436, 0.35583141, 0.0165229, 0.4342072, 0.11243304],
 [0.5367969, 0.30878091, 0.41187929, 0.38822518, 0.5225283],
 [0.95773967, 0.23566857, 0.09914585, 0.15680593, 0.07131737],
 [0.6293079, 0.80348368, 0.81140844, 0.04561319, 0.11062446],
 [0.02173531, 0.42808424, 0.83593944, 0.48948866, 0.51108173],
 [0.43934426, 0.69892383, 0.42682022, 0.10947609, 0.87788847],
 [0.25890557, 0.79367771, 0.6421139, 0.19667346, 0.59310318],
 [0.43216593, 0.71561781, 0.3418191, 0.70499988, 0.61496184],
 [0.78287982, 0.53633586, 0.44328356, 0.85969983, 0.01032599],
 [0.9217762, 0.93187122, 0.41487637, 0.59505727, 0.73562569],
 [0.12667892, 0.2914703, 0.06452848, 0.6805146, 0.89281919],
 [1.057739, 1.031871, 1.078805, 1.061655, 0.992819],
 [0.183405, 0.304243, 0.524756, 0.431945, 0.29123 ],
 [0.268807, 0.268756, 0.495982, 0.986904, 0.010463],
 [0.071886, 0.119564, 0.11427 , 0.97486 , 0.062381],
 [0.985053, 0.912856, 0.967723, 0.993021, 0.944062],
 [0.985053, 0.912856, 0.967723, 0.993021, 0.944062],
 [0.289326, 0.014308, 0.819185, 0.769045, 0.018673],
 [0.437318, 0.251829, 0.542272, 0.788906, 0.000000]
], dtype=float)

y_raw = np.array([
 -0.71426495, -1.20995524, -1.67219994, -1.53605771, -0.82923655,
 -1.24704893, -1.23378638, -1.69434344, -2.57116963, -1.30911635,
 -1.14478485, -1.91267714, -1.62283895, -1.35668211, -2.0184254,
 -1.70255784, -1.29424696, -0.93575656, -2.15576776, -1.74688209,
 -2.868905011263093, -0.9489046340640067, -0.6674108573004914,
 -1.3769650251311083, -2.5104529076756172, -2.5498833751068073,
 -0.7529123509459484, -0.36323892495106164
], dtype=float)

assert X_raw.shape[0] == y_raw.shape[0], "X and y must have the same number of rows."

# -----------------------------
# 2) Device & Seeds
# -----------------------------
RANDOM_SEED = 123
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# -----------------------------
# 3) Data hygiene (clamp + dedup)
# -----------------------------
def clamp01(X):
    return np.clip(X, 0.0, 1.0)

def dedup_average(X, y, tol=0.0):
    if tol > 0:
        X_key = np.round(X / tol) * tol
    else:
        X_key = X.copy()

    keys = [row.tobytes() for row in X_key]
    buckets = {}
    for i, k in enumerate(keys):
        buckets.setdefault(k, []).append(i)

    X_new, y_new = [], []
    for k, idxs in buckets.items():
        X_new.append(X[idxs[0]])
        y_new.append(float(np.mean(y[idxs])))
    return np.array(X_new, dtype=float), np.array(y_new, dtype=float)

X_raw = clamp01(X_raw)
X_raw, y_raw = dedup_average(X_raw, y_raw, tol=0.0)

# -----------------------------
# 4) Scaling
# -----------------------------
x_scaler = StandardScaler()
y_scaler = StandardScaler()
X_scaled = x_scaler.fit_transform(X_raw)
y_scaled = y_scaler.fit_transform(y_raw.reshape(-1, 1)).ravel()

X_tensor_all = torch.tensor(X_scaled, dtype=torch.float32, device=device)
y_tensor_all = torch.tensor(y_scaled.reshape(-1, 1), dtype=torch.float32, device=device)

# -----------------------------
# 5) Surrogate Model
# -----------------------------
class SurrogateNN(nn.Module):
    def __init__(self, input_dim=5, hidden_layers=(128, 64), dropout_p=0.05, use_layernorm=True):
        super().__init__()
        layers = []
        prev = input_dim
        for h in hidden_layers:
            layers.append(nn.Linear(prev, h))
            if use_layernorm:
                layers.append(nn.LayerNorm(h))
            layers.append(nn.GELU())
            layers.append(nn.Dropout(dropout_p))
            prev = h
        layers.append(nn.Linear(prev, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)

# -----------------------------
# 6) Training helper
# -----------------------------
def train_with_early_stopping(model, optimizer, criterion,
                              X_train, y_train, X_val, y_val,
                              max_epochs=1200, patience=180, min_epochs=120):
    best_state = None
    best_val = float("inf")
    no_improve = 0

    for ep in range(1, max_epochs + 1):
        model.train()
        optimizer.zero_grad(set_to_none=True)
        pred = model(X_train)
        loss = criterion(pred, y_train)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
        optimizer.step()

        model.eval()
        with torch.no_grad():
            val_pred = model(X_val)
            val_loss = criterion(val_pred, y_val).item()

        if val_loss < best_val - 1e-6:
            best_val = val_loss
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
            no_improve = 0
        else:
            if ep >= min_epochs:
                no_improve += 1

        if ep >= min_epochs and no_improve >= patience:
            break

    if best_state is not None:
        model.load_state_dict({k: v.to(device) for k, v in best_state.items()})
    return best_val

# -----------------------------
# 7) Hyperparameter tuning (Successive Halving)
# -----------------------------
def sample_log_uniform(rng, lo, hi):
    return float(np.exp(rng.uniform(np.log(lo), np.log(hi))))

def sample_config(rng):
    hidden_choices = [(64, 64), (128, 64), (128, 128), (256, 128)]
    dropout_choices = [0.0, 0.03, 0.06, 0.10, 0.16]
    ln_choices = [True, False]
    return {
        "hidden_layers": hidden_choices[rng.integers(0, len(hidden_choices))],
        "dropout": float(dropout_choices[rng.integers(0, len(dropout_choices))]),
        "lr": sample_log_uniform(rng, 4e-4, 4e-3),
        "weight_decay": sample_log_uniform(rng, 1e-7, 3e-4),
        "use_layernorm": bool(rng.choice(ln_choices)),
        "n_ensemble": int(rng.choice([5, 7])),
        # base exploration; final xi is scaled by n and uncertainty later
        "xi_base": float(rng.choice([0.0, 0.005, 0.01, 0.02])),
    }

def cv_score_config(cfg, X_all, y_all, seed=123, n_splits=4,
                    max_epochs=600, patience=120, min_epochs=80):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=seed)
    criterion = nn.MSELoss()
    vals = []
    for tr_idx, va_idx in kf.split(X_all):
        X_tr = X_all[tr_idx]
        y_tr = y_all[tr_idx]
        X_va = X_all[va_idx]
        y_va = y_all[va_idx]

        model = SurrogateNN(
            input_dim=5,
            hidden_layers=cfg["hidden_layers"],
            dropout_p=cfg["dropout"],
            use_layernorm=cfg["use_layernorm"]
        ).to(device)

        optimizer = optim.AdamW(model.parameters(), lr=cfg["lr"], weight_decay=cfg["weight_decay"])
        val = train_with_early_stopping(
            model, optimizer, criterion,
            X_tr, y_tr, X_va, y_va,
            max_epochs=max_epochs, patience=patience, min_epochs=min_epochs
        )
        vals.append(val)
    return float(np.mean(vals))

def tune_hyperparameters_successive_halving(X_all, y_all, seed=123):
    rng = np.random.default_rng(seed)

    # Stage budgets (cheap -> expensive)
    stages = [
        {"n_cfg": 18, "keep": 6, "epochs": 350, "splits": 3},
        {"n_cfg": 6,  "keep": 2, "epochs": 650, "splits": 4},
        {"n_cfg": 2,  "keep": 1, "epochs": 1100, "splits": 5},
    ]

    cfgs = [sample_config(rng) for _ in range(stages[0]["n_cfg"])]

    for si, st in enumerate(stages, 1):
        scores = []
        for i, cfg in enumerate(cfgs, 1):
            sc = cv_score_config(
                cfg, X_all, y_all, seed=seed,
                n_splits=st["splits"],
                max_epochs=st["epochs"],
                patience=max(90, int(0.20 * st["epochs"])),
                min_epochs=max(60, int(0.12 * st["epochs"]))
            )
            scores.append(sc)
            print(f"[SH stage {si}] cfg {i:02d}/{len(cfgs)} | CV-MSE={sc:.6f} | {cfg}")

        order = np.argsort(scores)  # lower is better
        cfgs = [cfgs[j] for j in order[:st["keep"]]]
        best_sc = float(scores[order[0]])
        best_cfg = cfgs[0]
        print(f"\n[SH stage {si}] best so far: {best_sc:.6f} | {best_cfg}\n")

    return best_cfg, best_sc

# -----------------------------
# 8) Deep Ensemble fit + predict
# -----------------------------
def fit_ensemble(cfg, X_all, y_all, base_seed=123):
    models = []
    criterion = nn.MSELoss()
    n = X_all.shape[0]

    for m in range(cfg["n_ensemble"]):
        rng = np.random.default_rng(base_seed + 10_000 + m)
        boot = rng.integers(0, n, size=n)
        X_b = X_all[boot]
        y_b = y_all[boot]

        idx = torch.randperm(n, device=device)
        n_train = max(int(0.85 * n), 1)
        tr_idx, va_idx = idx[:n_train], idx[n_train:]

        model = SurrogateNN(
            input_dim=5,
            hidden_layers=cfg["hidden_layers"],
            dropout_p=cfg["dropout"],
            use_layernorm=cfg["use_layernorm"]
        ).to(device)

        optimizer = optim.AdamW(model.parameters(), lr=cfg["lr"], weight_decay=cfg["weight_decay"])
        train_with_early_stopping(
            model, optimizer, criterion,
            X_b[tr_idx], y_b[tr_idx],
            X_b[va_idx], y_b[va_idx],
            max_epochs=1200, patience=180, min_epochs=120
        )

        models.append(model)

    return models

@torch.no_grad()
def predict_ensemble(models, X_candidates):
    X_scaled_cand = x_scaler.transform(X_candidates)
    X_t = torch.tensor(X_scaled_cand, dtype=torch.float32, device=device)

    preds_scaled = []
    for model in models:
        model.eval()
        preds_scaled.append(model(X_t).detach().cpu().numpy())  # [n,1]

    preds_scaled = np.stack(preds_scaled, axis=0).squeeze(-1)  # [E, n]
    flat = preds_scaled.reshape(-1, 1)
    orig = y_scaler.inverse_transform(flat).reshape(preds_scaled.shape)

    mu = orig.mean(axis=0)
    sigma = orig.std(axis=0)
    return mu, sigma, orig  # also return per-member predictions for qEI

# -----------------------------
# 9) Acquisition utils (EI + qEI)
# -----------------------------
def normal_pdf(z):
    return np.exp(-0.5 * z**2) / math.sqrt(2 * math.pi)

def normal_cdf(z):
    z = np.asarray(z)
    return 0.5 * (1 + np.vectorize(math.erf)(z / math.sqrt(2)))

def acquisition_ei(mu, sigma, y_best, xi=0.0):
    eps = 1e-9
    sigma = np.maximum(sigma, eps)
    improvement = mu - y_best - xi
    Z = improvement / sigma
    ei = improvement * normal_cdf(Z) + sigma * normal_pdf(Z)
    return np.maximum(ei, 0.0)

def qei_mc(preds_members, y_best, xi=0.0, n_mc=64, seed=123):
    """
    qEI approximation:
      - sample from empirical ensemble distribution (member bootstrap)
      - compute average improvement above (y_best+xi)
    preds_members: shape [E, N]
    """
    rng = np.random.default_rng(seed)
    E, N = preds_members.shape
    idx = rng.integers(0, E, size=(n_mc, N))
    samples = preds_members[idx, np.arange(N)[None, :]]  # [n_mc, N]
    improv = samples - (y_best + xi)
    improv = np.maximum(improv, 0.0)
    return improv.mean(axis=0)

# -----------------------------
# 10) Candidate generation
# -----------------------------
def sobol_candidates(n, dim, seed=123):
    engine = torch.quasirandom.SobolEngine(dimension=dim, scramble=True, seed=seed)
    return engine.draw(n).cpu().numpy()

def trust_region_candidates(x_center, n, sigma=0.08, seed=123):
    rng = np.random.default_rng(seed)
    X = x_center.reshape(1, -1) + rng.normal(0.0, sigma, size=(n, x_center.size))
    return np.clip(X, 0.0, 1.0)

def min_dist_filter(X_cand, X_obs, min_dist=1e-3):
    diff = X_cand[:, None, :] - X_obs[None, :, :]
    d2 = np.sum(diff * diff, axis=2)
    return np.all(d2 >= (min_dist ** 2), axis=1)

def diversity_penalty(X_cand, X_obs, scale=0.02):
    """
    Penalty: exp(-d_min/scale) -> high penalty when very close to existing points.
    """
    diff = X_cand[:, None, :] - X_obs[None, :, :]
    d2 = np.sum(diff * diff, axis=2)
    dmin = np.sqrt(np.min(d2, axis=1) + 1e-12)
    return np.exp(-dmin / max(scale, 1e-6))

# -----------------------------
# 11) Propose next point (Week 9 logic)
# -----------------------------
def propose_next_points(models, X_obs, y_obs,
                        xi_base=0.01,
                        n_sobol=22000, n_local=9000,
                        random_seed=123,
                        min_dist=1e-3,
                        local_sigma=0.085,
                        top_k=10,
                        # emergent hedge:
                        hedge_frac=0.08,     # % of the time pick from hedge set
                        hedge_mode="ucb",    # "ucb" or "max_sigma"
                        # scaling-law exploration decay:
                        n_ref=12, alpha=0.7  # xi ~ (n_ref/n)^alpha
                        ):

    n = X_obs.shape[0]
    y_best = float(np.max(y_obs))
    y_min = float(np.min(y_obs))
    y_range = max(y_best - y_min, 1e-6)

    # exploitation center
    x_best_obs = X_obs[int(np.argmax(y_obs))]

    # scaling: as n grows, exploration decays (but not to zero)
    scale_n = (n_ref / max(n, 1.0)) ** alpha
    scale_n = float(np.clip(scale_n, 0.35, 1.25))

    # candidates: global + trust-region
    X_global = sobol_candidates(n_sobol, dim=5, seed=random_seed)
    X_local = trust_region_candidates(x_best_obs, n_local, sigma=local_sigma, seed=random_seed + 7)

    # emergent hedge candidates: far-random (uniform) in addition to Sobol/TR
    rng = np.random.default_rng(random_seed + 999)
    X_far = rng.random(size=(max(2000, int(0.08 * (n_sobol + n_local))), 5))

    X_cand = np.vstack([X_global, X_local, X_far])

    # distance filter
    keep = min_dist_filter(X_cand, X_obs, min_dist=min_dist)
    X_cand = X_cand[keep]

    # predict
    mu, sigma, preds_members = predict_ensemble(models, X_cand)

    # uncertainty-aware xi (reduces when model is confident; increases when uncertain)
    sigma_med = float(np.median(sigma))
    conf_scale = 1.0 / (1.0 + sigma_med)  # lower uncertainty -> closer to 1
    effective_xi = float(xi_base * y_range * conf_scale * scale_n)

    # robust qEI + diversity penalty
    qei = qei_mc(preds_members, y_best=y_best, xi=effective_xi, n_mc=96, seed=random_seed + 33)
    pen = diversity_penalty(X_cand, X_obs, scale=0.02)
    score_main = qei * (1.0 - 0.35 * pen)

    # emergent hedge scoring: pick points that model is most uncertain about
    if hedge_mode == "ucb":
        # exploration-only: mu + beta*sigma, but with a big beta
        beta = 2.5 + 2.0 * scale_n
        score_hedge = mu + beta * sigma
    else:
        score_hedge = sigma

    # Decide whether to hedge or exploit
    rng2 = np.random.default_rng(random_seed + 202)
    do_hedge = (rng2.random() < hedge_frac)

    if do_hedge:
        best_idx = int(np.argmax(score_hedge))
        chosen_mode = "HEDGE"
        chosen_score = float(score_hedge[best_idx])
    else:
        best_idx = int(np.argmax(score_main))
        chosen_mode = "MAIN(qEI)"
        chosen_score = float(score_main[best_idx])

    # shortlist by main score
    top_idx = np.argsort(-score_main)[:top_k]

    return {
        "x_next": X_cand[best_idx],
        "mu_next": float(mu[best_idx]),
        "sigma_next": float(sigma[best_idx]),
        "qei_next": float(qei[best_idx]),
        "chosen_mode": chosen_mode,
        "chosen_score": chosen_score,
        "x_best_obs": x_best_obs,
        "y_best_obs": y_best,
        "effective_xi": float(effective_xi),
        "n_candidates": int(X_cand.shape[0]),
        "topk": [
            {
                "rank": int(r + 1),
                "x": X_cand[i],
                "mu": float(mu[i]),
                "sigma": float(sigma[i]),
                "qei": float(qei[i]),
                "score": float(score_main[i]),
            }
            for r, i in enumerate(top_idx)
        ]
    }

# -----------------------------
# 12) Local sensitivity (use first ensemble member)
# -----------------------------
def local_sensitivity(model, x_point):
    model.eval()
    x_scaled = x_scaler.transform(x_point.reshape(1, -1))
    x_t = torch.tensor(x_scaled, dtype=torch.float32, device=device, requires_grad=True)

    y_pred = model(x_t)
    y_pred.backward()

    grads = x_t.grad.detach().cpu().numpy().flatten()
    g = np.abs(grads)
    if g.sum() == 0:
        return np.ones_like(g) / len(g)
    return g / g.sum()

# -----------------------------
# 13) Main
# -----------------------------
def main():
    print("\n================ WEEK 9 FUNCTION 6 — NEXT DATA POINT (<= 6 DECIMALS) ================\n")
    print(f"Data after clamp+dedup: n={X_raw.shape[0]} points")

    # Cheaper + robust tuning
    best_cfg, best_cv = tune_hyperparameters_successive_halving(
        X_tensor_all, y_tensor_all, seed=RANDOM_SEED
    )

    print("\n================ BEST TUNED CONFIG (Successive Halving) ================\n")
    print("Best CV-MSE (scaled y):", best_cv)
    print("Best config:", best_cfg)

    print("\n================ FITTING DEEP ENSEMBLE ================\n")
    ensemble_models = fit_ensemble(best_cfg, X_tensor_all, y_tensor_all, base_seed=RANDOM_SEED)

    # Candidate budget scales mildly with data size (scaling-law intuition: more data -> slightly less brute force)
    n = X_raw.shape[0]
    n_sobol = int(np.clip(26000 - 500 * (n - 12), 16000, 26000))
    n_local = int(np.clip(9000 + 300 * (n - 12), 7000, 12000))

    details = propose_next_points(
        ensemble_models,
        X_raw,
        y_raw,
        xi_base=best_cfg["xi_base"],
        n_sobol=n_sobol,
        n_local=n_local,
        random_seed=RANDOM_SEED,
        min_dist=1e-3,
        local_sigma=0.085,
        top_k=10,
        hedge_frac=0.10,      # slightly higher hedge in black-box setting
        hedge_mode="ucb",
        n_ref=12,
        alpha=0.7
    )

    x_next_6 = np.round(np.clip(details["x_next"].astype(float), 0.0, 1.0), 6)

    print("\n================ CURRENT BEST OBSERVED ================\n")
    print("x_best =", np.round(details["x_best_obs"].astype(float), 6))
    print("y_best =", round(details["y_best_obs"], 6))

    print("\n================ SETTINGS (Week 9) ================\n")
    print(f"- n_candidates_after_filter = {details['n_candidates']}")
    print(f"- effective_xi (scaled/decayed) = {details['effective_xi']:.6f}")
    print(f"- chosen_mode = {details['chosen_mode']} | chosen_score = {details['chosen_score']:.6f}")
    print(f"- n_sobol = {n_sobol} | n_local = {n_local}")

    print("\n================ NEXT DATA POINT (<= 6 DECIMALS) ================\n")
    # This is the value you submit
    print("x_next =", x_next_6)
    print("mu(x_next) =", round(details["mu_next"], 6))
    print("sigma(x_next) =", round(details["sigma_next"], 6))
    print("qEI_MC =", round(details["qei_next"], 6))

    print("\n================ TOP-10 SHORTLIST (by main score) — 6 DECIMALS ================\n")
    for row in details["topk"]:
        print(
            f"{row['rank']:02d}) x={np.round(row['x'].astype(float), 6)} | "
            f"mu={row['mu']:.6f} | sigma={row['sigma']:.6f} | qEI={row['qei']:.6f} | score={row['score']:.6f}"
        )

    print("\n================ LOCAL SENSITIVITY (ensemble member #1) ================\n")
    sens = local_sensitivity(ensemble_models[0], details["x_next"])
    for i, s in enumerate(sens, 1):
        print(f"Dim {i}: {s:.3f}")

if __name__ == "__main__":
    main()
# Out:
# ================ WEEK 9 FUNCTION 6 — NEXT DATA POINT (<= 6 DECIMALS) ================
#
# Data after clamp+dedup: n=27 points
# [SH stage 1] cfg 01/18 | CV-MSE=0.457834 | {'hidden_layers': (64, 64), 'dropout': 0.1, 'lr': 0.00045277351007438286, 'weight_decay': 5.837380423441397e-07, 'use_layernorm': True, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 1] cfg 02/18 | CV-MSE=0.273083 | {'hidden_layers': (64, 64), 'dropout': 0.03, 'lr': 0.003352779476383228, 'weight_decay': 9.15551370547805e-07, 'use_layernorm': False, 'n_ensemble': 7, 'xi_base': 0.02}
# [SH stage 1] cfg 03/18 | CV-MSE=0.354245 | {'hidden_layers': (256, 128), 'dropout': 0.16, 'lr': 0.0013032581411905396, 'weight_decay': 7.108396118035575e-07, 'use_layernorm': True, 'n_ensemble': 7, 'xi_base': 0.02}
# [SH stage 1] cfg 04/18 | CV-MSE=0.287051 | {'hidden_layers': (64, 64), 'dropout': 0.06, 'lr': 0.0017060831586461437, 'weight_decay': 0.00016776736768971655, 'use_layernorm': False, 'n_ensemble': 7, 'xi_base': 0.0}
# [SH stage 1] cfg 05/18 | CV-MSE=0.385279 | {'hidden_layers': (256, 128), 'dropout': 0.1, 'lr': 0.0013189399657074516, 'weight_decay': 6.384795396961156e-07, 'use_layernorm': True, 'n_ensemble': 5, 'xi_base': 0.0}
# [SH stage 1] cfg 06/18 | CV-MSE=0.197666 | {'hidden_layers': (128, 64), 'dropout': 0.0, 'lr': 0.0006115021365273104, 'weight_decay': 1.1266562536616612e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 1] cfg 07/18 | CV-MSE=0.202410 | {'hidden_layers': (64, 64), 'dropout': 0.1, 'lr': 0.003316350949615086, 'weight_decay': 1.4964340681826228e-05, 'use_layernorm': False, 'n_ensemble': 7, 'xi_base': 0.01}
# [SH stage 1] cfg 08/18 | CV-MSE=0.393998 | {'hidden_layers': (256, 128), 'dropout': 0.06, 'lr': 0.0029389176837015677, 'weight_decay': 3.474666201818485e-05, 'use_layernorm': True, 'n_ensemble': 7, 'xi_base': 0.005}
# [SH stage 1] cfg 09/18 | CV-MSE=0.263076 | {'hidden_layers': (128, 64), 'dropout': 0.1, 'lr': 0.0029327949794944433, 'weight_decay': 1.099466171269843e-06, 'use_layernorm': False, 'n_ensemble': 7, 'xi_base': 0.01}
# [SH stage 1] cfg 10/18 | CV-MSE=0.182597 | {'hidden_layers': (64, 64), 'dropout': 0.03, 'lr': 0.0006917774337966829, 'weight_decay': 4.569528106521275e-05, 'use_layernorm': False, 'n_ensemble': 7, 'xi_base': 0.0}
# [SH stage 1] cfg 11/18 | CV-MSE=0.400607 | {'hidden_layers': (128, 128), 'dropout': 0.03, 'lr': 0.0004135561352482403, 'weight_decay': 1.297737870883513e-07, 'use_layernorm': True, 'n_ensemble': 5, 'xi_base': 0.01}
# [SH stage 1] cfg 12/18 | CV-MSE=0.666439 | {'hidden_layers': (128, 64), 'dropout': 0.16, 'lr': 0.0007238065289205709, 'weight_decay': 1.025796239733974e-07, 'use_layernorm': True, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 1] cfg 13/18 | CV-MSE=0.419772 | {'hidden_layers': (128, 128), 'dropout': 0.06, 'lr': 0.0010699383704841474, 'weight_decay': 8.012206274545792e-05, 'use_layernorm': True, 'n_ensemble': 7, 'xi_base': 0.0}
# [SH stage 1] cfg 14/18 | CV-MSE=0.216345 | {'hidden_layers': (128, 64), 'dropout': 0.06, 'lr': 0.0012634170737524286, 'weight_decay': 4.3498621637118784e-05, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.01}
# [SH stage 1] cfg 15/18 | CV-MSE=0.146337 | {'hidden_layers': (256, 128), 'dropout': 0.06, 'lr': 0.0009958970266546463, 'weight_decay': 1.1948538636335782e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 1] cfg 16/18 | CV-MSE=0.184373 | {'hidden_layers': (128, 128), 'dropout': 0.06, 'lr': 0.0010898985417074698, 'weight_decay': 4.882407733169447e-06, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.01}
# [SH stage 1] cfg 17/18 | CV-MSE=0.129121 | {'hidden_layers': (128, 128), 'dropout': 0.06, 'lr': 0.0015165464269857258, 'weight_decay': 1.7563773235675597e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 1] cfg 18/18 | CV-MSE=0.241724 | {'hidden_layers': (128, 128), 'dropout': 0.0, 'lr': 0.00107619336890803, 'weight_decay': 1.129483085778142e-06, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.0}
#
# [SH stage 1] best so far: 0.129121 | {'hidden_layers': (128, 128), 'dropout': 0.06, 'lr': 0.0015165464269857258, 'weight_decay': 1.7563773235675597e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
#
# [SH stage 2] cfg 01/6 | CV-MSE=0.124956 | {'hidden_layers': (128, 128), 'dropout': 0.06, 'lr': 0.0015165464269857258, 'weight_decay': 1.7563773235675597e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 2] cfg 02/6 | CV-MSE=0.108762 | {'hidden_layers': (256, 128), 'dropout': 0.06, 'lr': 0.0009958970266546463, 'weight_decay': 1.1948538636335782e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 2] cfg 03/6 | CV-MSE=0.154358 | {'hidden_layers': (64, 64), 'dropout': 0.03, 'lr': 0.0006917774337966829, 'weight_decay': 4.569528106521275e-05, 'use_layernorm': False, 'n_ensemble': 7, 'xi_base': 0.0}
# [SH stage 2] cfg 04/6 | CV-MSE=0.122649 | {'hidden_layers': (128, 128), 'dropout': 0.06, 'lr': 0.0010898985417074698, 'weight_decay': 4.882407733169447e-06, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.01}
# [SH stage 2] cfg 05/6 | CV-MSE=0.124804 | {'hidden_layers': (128, 64), 'dropout': 0.0, 'lr': 0.0006115021365273104, 'weight_decay': 1.1266562536616612e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 2] cfg 06/6 | CV-MSE=0.112826 | {'hidden_layers': (64, 64), 'dropout': 0.1, 'lr': 0.003316350949615086, 'weight_decay': 1.4964340681826228e-05, 'use_layernorm': False, 'n_ensemble': 7, 'xi_base': 0.01}
#
# [SH stage 2] best so far: 0.108762 | {'hidden_layers': (256, 128), 'dropout': 0.06, 'lr': 0.0009958970266546463, 'weight_decay': 1.1948538636335782e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
#
# [SH stage 3] cfg 01/2 | CV-MSE=0.114213 | {'hidden_layers': (256, 128), 'dropout': 0.06, 'lr': 0.0009958970266546463, 'weight_decay': 1.1948538636335782e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 3] cfg 02/2 | CV-MSE=0.114243 | {'hidden_layers': (64, 64), 'dropout': 0.1, 'lr': 0.003316350949615086, 'weight_decay': 1.4964340681826228e-05, 'use_layernorm': False, 'n_ensemble': 7, 'xi_base': 0.01}
#
# [SH stage 3] best so far: 0.114213 | {'hidden_layers': (256, 128), 'dropout': 0.06, 'lr': 0.0009958970266546463, 'weight_decay': 1.1948538636335782e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
#
#
# ================ BEST TUNED CONFIG (Successive Halving) ================
#
# Best CV-MSE (scaled y): 0.1142132680863142
# Best config: {'hidden_layers': (256, 128), 'dropout': 0.06, 'lr': 0.0009958970266546463, 'weight_decay': 1.1948538636335782e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
#
# ================ FITTING DEEP ENSEMBLE ================
#
#
# ================ CURRENT BEST OBSERVED ================
#
# x_best = [0.437318 0.251829 0.542272 0.788906 0.      ]
# y_best = -0.363239
#
# ================ SETTINGS (Week 9) ================
#
# - n_candidates_after_filter = 32940
# - effective_xi (scaled/decayed) = 0.006064
# - chosen_mode = MAIN(qEI) | chosen_score = 0.033377
# - n_sobol = 18500 | n_local = 12000
#
# ================ NEXT DATA POINT (<= 6 DECIMALS) ================
#
# x_next = [0.39532  0.238886 0.702458 0.805605 0.      ]
# mu(x_next) = -0.519189
# sigma(x_next) = 0.20884
# qEI_MC = 0.03338
#
# ================ TOP-10 SHORTLIST (by main score) — 6 DECIMALS ================
#
# 01) x=[0.39532  0.238886 0.702458 0.805605 0.      ] | mu=-0.519189 | sigma=0.208840 | qEI=0.033380 | score=0.033377
# 02) x=[0.389042 0.288104 0.739169 0.846614 0.      ] | mu=-0.537323 | sigma=0.212568 | qEI=0.031901 | score=0.031901
# 03) x=[0.337365 0.298342 0.768786 0.755787 0.      ] | mu=-0.529229 | sigma=0.220581 | qEI=0.030106 | score=0.030106
# 04) x=[0.370544 0.238239 0.666224 0.775828 0.      ] | mu=-0.516252 | sigma=0.214107 | qEI=0.029503 | score=0.029494
# 05) x=[0.418833 0.251211 0.691148 0.834141 0.      ] | mu=-0.528152 | sigma=0.203335 | qEI=0.029036 | score=0.029032
# 06) x=[0.371308 0.221127 0.686678 0.763435 0.      ] | mu=-0.512330 | sigma=0.212663 | qEI=0.029005 | score=0.029002
# 07) x=[0.395072 0.231562 0.692977 0.784876 0.      ] | mu=-0.514058 | sigma=0.209121 | qEI=0.028574 | score=0.028571
# 08) x=[0.346167 0.141084 0.755095 0.724357 0.      ] | mu=-0.520642 | sigma=0.203604 | qEI=0.028515 | score=0.028511
# 09) x=[0.360875 0.259372 0.764989 0.848567 0.005516] | mu=-0.546678 | sigma=0.216037 | qEI=0.028390 | score=0.028390
# 10) x=[0.392282 0.255469 0.693589 0.764244 0.      ] | mu=-0.510365 | sigma=0.213336 | qEI=0.028189 | score=0.028186
#
# ================ LOCAL SENSITIVITY (ensemble member #1) ================
#
# Dim 1: 0.329
# Dim 2: 0.283
# Dim 3: 0.136
# Dim 4: 0.112
# Dim 5: 0.139
