# %%
import numpy as np
import math
import torch
import torch.nn as nn
import torch.optim as optim
from dataclasses import dataclass, asdict
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold

# =========================================================
# WEEK 10 — FUNCTION 6 (TRANSPARENCY + INTERPRETABILITY BO)
# Goal: propose x_next in [0,1]^5 (<= 6 decimals) targeting local maxima.
#
# What changed vs Week 9 (to improve transparency / reproducibility):
#  1) Full "decision report" (audit trail) printed at the end:
#       - data hygiene summary, best observed, parameter choices
#       - candidate-source breakdown (Sobol / TR / Far-random)
#       - nearest-neighbour distance of x_next (anti-duplicate evidence)
#       - why chosen (MAIN qEI vs HEDGE)
#  2) Explicit assumptions made visible:
#       - smoothness/locality assumption -> trust region around best
#       - uncertainty is meaningful -> ensemble std used for hedge
#  3) Dataset gaps / sampling bias diagnostics:
#       - per-dimension coverage stats, boundary proximity counts
#       - pairwise distance summary (how clustered the data is)
#  4) Interpretability hooks:
#       - local gradient sensitivity (per-dim importance) for x_next
#       - simple "one-at-a-time" perturbation probe around x_next
#  5) Reproducibility:
#       - single RANDOM_SEED controls all RNGs
#       - config + key scalars recorded and printed
# =========================================================

# -----------------------------
# 1) Data (as provided)
# -----------------------------
X_raw = np.array([
 [0.7281861, 0.15469257, 0.73255167, 0.69399651, 0.05640131],
 [0.24238435, 0.84409997, 0.5778091, 0.67902128, 0.50195289],
 [0.72952261, 0.7481062, 0.67977464, 0.35655228, 0.67105368],
 [0.77062024, 0.11440374, 0.04677993, 0.64832428, 0.27354905],
 [0.6188123, 0.33180214, 0.18728787, 0.75623847, 0.3288348],
 [0.78495809, 0.91068235, 0.7081201, 0.95922543, 0.0049115],
 [0.14511079, 0.8966846, 0.89632223, 0.72627154, 0.23627199],
 [0.94506907, 0.28845905, 0.97880576, 0.96165559, 0.59801594],
 [0.12572016, 0.86272469, 0.02854433, 0.24660527, 0.75120624],
 [0.75759436, 0.35583141, 0.0165229, 0.4342072, 0.11243304],
 [0.5367969, 0.30878091, 0.41187929, 0.38822518, 0.5225283],
 [0.95773967, 0.23566857, 0.09914585, 0.15680593, 0.07131737],
 [0.6293079, 0.80348368, 0.81140844, 0.04561319, 0.11062446],
 [0.02173531, 0.42808424, 0.83593944, 0.48948866, 0.51108173],
 [0.43934426, 0.69892383, 0.42682022, 0.10947609, 0.87788847],
 [0.25890557, 0.79367771, 0.6421139, 0.19667346, 0.59310318],
 [0.43216593, 0.71561781, 0.3418191, 0.70499988, 0.61496184],
 [0.78287982, 0.53633586, 0.44328356, 0.85969983, 0.01032599],
 [0.9217762, 0.93187122, 0.41487637, 0.59505727, 0.73562569],
 [0.12667892, 0.2914703, 0.06452848, 0.6805146, 0.89281919],
 [1.057739, 1.031871, 1.078805, 1.061655, 0.992819],
 [0.183405, 0.304243, 0.524756, 0.431945, 0.29123 ],
 [0.268807, 0.268756, 0.495982, 0.986904, 0.010463],
 [0.071886, 0.119564, 0.11427 , 0.97486 , 0.062381],
 [0.985053, 0.912856, 0.967723, 0.993021, 0.944062],
 [0.985053, 0.912856, 0.967723, 0.993021, 0.944062],
 [0.289326, 0.014308, 0.819185, 0.769045, 0.018673],
 [0.437318, 0.251829, 0.542272, 0.788906, 0.000000],
 [0.395320, 0.238886, 0.702458, 0.805605, 0.000000]
], dtype=float)

y_raw = np.array([
 -0.71426495, -1.20995524, -1.67219994, -1.53605771, -0.82923655,
 -1.24704893, -1.23378638, -1.69434344, -2.57116963, -1.30911635,
 -1.14478485, -1.91267714, -1.62283895, -1.35668211, -2.0184254,
 -1.70255784, -1.29424696, -0.93575656, -2.15576776, -1.74688209,
 -2.868905011263093, -0.9489046340640067, -0.6674108573004914,
 -1.3769650251311083, -2.5104529076756172, -2.5498833751068073,
 -0.7529123509459484, -0.36323892495106164, -0.29318472382773614
], dtype=float)

assert X_raw.shape[0] == y_raw.shape[0], "X and y must have the same number of rows."
assert X_raw.shape[1] == 5, "Function 6 expected dimension=5."

# -----------------------------
# 2) Device & Seeds (reproducibility)
# -----------------------------
RANDOM_SEED = 123
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
torch.cuda.manual_seed_all(RANDOM_SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# -----------------------------
# 3) Data hygiene (clamp + dedup)
# -----------------------------
def clamp01(X):
    return np.clip(X, 0.0, 1.0)

def dedup_average(X, y, tol=0.0):
    """
    If duplicate X rows exist, average their y values.
    tol=0.0 => exact duplicates only (byte-wise).
    """
    if tol > 0:
        X_key = np.round(X / tol) * tol
    else:
        X_key = X.copy()

    keys = [row.tobytes() for row in X_key]
    buckets = {}
    for i, k in enumerate(keys):
        buckets.setdefault(k, []).append(i)

    X_new, y_new = [], []
    for _, idxs in buckets.items():
        X_new.append(X[idxs[0]])
        y_new.append(float(np.mean(y[idxs])))
    return np.array(X_new, dtype=float), np.array(y_new, dtype=float), buckets

X_raw = clamp01(X_raw)
X_raw, y_raw, dedup_buckets = dedup_average(X_raw, y_raw, tol=0.0)

# -----------------------------
# 4) Scaling
# -----------------------------
x_scaler = StandardScaler()
y_scaler = StandardScaler()
X_scaled = x_scaler.fit_transform(X_raw)
y_scaled = y_scaler.fit_transform(y_raw.reshape(-1, 1)).ravel()

X_tensor_all = torch.tensor(X_scaled, dtype=torch.float32, device=device)
y_tensor_all = torch.tensor(y_scaled.reshape(-1, 1), dtype=torch.float32, device=device)

# -----------------------------
# 5) Surrogate Model
# -----------------------------
class SurrogateNN(nn.Module):
    def __init__(self, input_dim=5, hidden_layers=(128, 64), dropout_p=0.05, use_layernorm=True):
        super().__init__()
        layers = []
        prev = input_dim
        for h in hidden_layers:
            layers.append(nn.Linear(prev, h))
            if use_layernorm:
                layers.append(nn.LayerNorm(h))
            layers.append(nn.GELU())
            layers.append(nn.Dropout(dropout_p))
            prev = h
        layers.append(nn.Linear(prev, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)

# -----------------------------
# 6) Training helper
# -----------------------------
def train_with_early_stopping(model, optimizer, criterion,
                              X_train, y_train, X_val, y_val,
                              max_epochs=1200, patience=180, min_epochs=120):
    best_state = None
    best_val = float("inf")
    no_improve = 0

    for ep in range(1, max_epochs + 1):
        model.train()
        optimizer.zero_grad(set_to_none=True)
        pred = model(X_train)
        loss = criterion(pred, y_train)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
        optimizer.step()

        model.eval()
        with torch.no_grad():
            val_pred = model(X_val)
            val_loss = criterion(val_pred, y_val).item()

        if val_loss < best_val - 1e-6:
            best_val = val_loss
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
            no_improve = 0
        else:
            if ep >= min_epochs:
                no_improve += 1

        if ep >= min_epochs and no_improve >= patience:
            break

    if best_state is not None:
        model.load_state_dict({k: v.to(device) for k, v in best_state.items()})
    return best_val

# -----------------------------
# 7) Hyperparameter tuning (Successive Halving, but logged)
# -----------------------------
def sample_log_uniform(rng, lo, hi):
    return float(np.exp(rng.uniform(np.log(lo), np.log(hi))))

@dataclass(frozen=True)
class BOConfig:
    hidden_layers: tuple
    dropout: float
    lr: float
    weight_decay: float
    use_layernorm: bool
    n_ensemble: int
    xi_base: float

def sample_config(rng) -> BOConfig:
    hidden_choices = [(64, 64), (128, 64), (128, 128), (256, 128)]
    dropout_choices = [0.0, 0.03, 0.06, 0.10, 0.16]
    ln_choices = [True, False]
    return BOConfig(
        hidden_layers=hidden_choices[rng.integers(0, len(hidden_choices))],
        dropout=float(dropout_choices[rng.integers(0, len(dropout_choices))]),
        lr=sample_log_uniform(rng, 4e-4, 4e-3),
        weight_decay=sample_log_uniform(rng, 1e-7, 3e-4),
        use_layernorm=bool(rng.choice(ln_choices)),
        n_ensemble=int(rng.choice([5, 7])),
        # base exploration; final xi is scaled by n and uncertainty later
        xi_base=float(rng.choice([0.0, 0.005, 0.01, 0.02])),
    )

def cv_score_config(cfg: BOConfig, X_all, y_all, seed=123, n_splits=4,
                    max_epochs=600, patience=120, min_epochs=80):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=seed)
    criterion = nn.MSELoss()
    vals = []
    for tr_idx, va_idx in kf.split(X_all):
        X_tr = X_all[tr_idx]
        y_tr = y_all[tr_idx]
        X_va = X_all[va_idx]
        y_va = y_all[va_idx]

        model = SurrogateNN(
            input_dim=5,
            hidden_layers=cfg.hidden_layers,
            dropout_p=cfg.dropout,
            use_layernorm=cfg.use_layernorm
        ).to(device)

        optimizer = optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
        val = train_with_early_stopping(
            model, optimizer, criterion,
            X_tr, y_tr, X_va, y_va,
            max_epochs=max_epochs, patience=patience, min_epochs=min_epochs
        )
        vals.append(val)
    return float(np.mean(vals))

def tune_hyperparameters_successive_halving(X_all, y_all, seed=123):
    """
    Transparent Successive Halving:
    - Stage 1: broad/cheap screen
    - Stage 2: narrower/deeper
    - Stage 3: final confirm
    """
    rng = np.random.default_rng(seed)

    stages = [
        {"n_cfg": 18, "keep": 6, "epochs": 350, "splits": 3},
        {"n_cfg": 6,  "keep": 2, "epochs": 650, "splits": 4},
        {"n_cfg": 2,  "keep": 1, "epochs": 1100, "splits": 5},
    ]

    cfgs = [sample_config(rng) for _ in range(stages[0]["n_cfg"])]

    stage_logs = []
    for si, st in enumerate(stages, 1):
        scores = []
        for i, cfg in enumerate(cfgs, 1):
            sc = cv_score_config(
                cfg, X_all, y_all, seed=seed,
                n_splits=st["splits"],
                max_epochs=st["epochs"],
                patience=max(90, int(0.20 * st["epochs"])),
                min_epochs=max(60, int(0.12 * st["epochs"]))
            )
            scores.append(sc)
            print(f"[SH stage {si}] cfg {i:02d}/{len(cfgs)} | CV-MSE={sc:.6f} | {asdict(cfg)}")

        order = np.argsort(scores)  # lower is better
        kept = [cfgs[j] for j in order[:st["keep"]]]
        best_sc = float(scores[order[0]])
        best_cfg = kept[0]
        stage_logs.append({
            "stage": si,
            "epochs": st["epochs"],
            "splits": st["splits"],
            "kept": st["keep"],
            "best_cv_mse": best_sc,
            "best_cfg": asdict(best_cfg),
        })

        print(f"\n[SH stage {si}] best so far: {best_sc:.6f} | {asdict(best_cfg)}\n")
        cfgs = kept

    return best_cfg, best_sc, stage_logs

# -----------------------------
# 8) Deep Ensemble fit + predict
# -----------------------------
def fit_ensemble(cfg: BOConfig, X_all, y_all, base_seed=123):
    models = []
    criterion = nn.MSELoss()
    n = X_all.shape[0]

    for m in range(cfg.n_ensemble):
        rng = np.random.default_rng(base_seed + 10_000 + m)
        boot = rng.integers(0, n, size=n)
        X_b = X_all[boot]
        y_b = y_all[boot]

        idx = torch.randperm(n, device=device)
        n_train = max(int(0.85 * n), 1)
        tr_idx, va_idx = idx[:n_train], idx[n_train:]

        model = SurrogateNN(
            input_dim=5,
            hidden_layers=cfg.hidden_layers,
            dropout_p=cfg.dropout,
            use_layernorm=cfg.use_layernorm
        ).to(device)

        optimizer = optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
        train_with_early_stopping(
            model, optimizer, criterion,
            X_b[tr_idx], y_b[tr_idx],
            X_b[va_idx], y_b[va_idx],
            max_epochs=1200, patience=180, min_epochs=120
        )

        models.append(model)

    return models

@torch.no_grad()
def predict_ensemble(models, X_candidates):
    X_scaled_cand = x_scaler.transform(X_candidates)
    X_t = torch.tensor(X_scaled_cand, dtype=torch.float32, device=device)

    preds_scaled = []
    for model in models:
        model.eval()
        preds_scaled.append(model(X_t).detach().cpu().numpy())  # [N,1]

    preds_scaled = np.stack(preds_scaled, axis=0).squeeze(-1)  # [E, N]
    flat = preds_scaled.reshape(-1, 1)
    orig = y_scaler.inverse_transform(flat).reshape(preds_scaled.shape)

    mu = orig.mean(axis=0)
    sigma = orig.std(axis=0)
    return mu, sigma, orig  # per-member for qEI

# -----------------------------
# 9) Acquisition (qEI) + helpers
# -----------------------------
def qei_mc(preds_members, y_best, xi=0.0, n_mc=96, seed=123):
    """
    qEI via empirical ensemble sampling:
      - sample member predictions (bootstrap proxy)
      - compute average positive improvement above y_best+xi
    preds_members: [E, N]
    """
    rng = np.random.default_rng(seed)
    E, N = preds_members.shape
    idx = rng.integers(0, E, size=(n_mc, N))
    samples = preds_members[idx, np.arange(N)[None, :]]  # [n_mc, N]
    improv = np.maximum(samples - (y_best + xi), 0.0)
    return improv.mean(axis=0)

def pairwise_min_dist(X_cand, X_obs):
    diff = X_cand[:, None, :] - X_obs[None, :, :]
    d2 = np.sum(diff * diff, axis=2)
    dmin = np.sqrt(np.min(d2, axis=1) + 1e-12)
    return dmin

def min_dist_filter(X_cand, X_obs, min_dist=1e-3):
    dmin = pairwise_min_dist(X_cand, X_obs)
    return dmin >= min_dist

def diversity_penalty_from_dmin(dmin, scale=0.02):
    # exp(-d/scale): near points => penalty near 1; far => ~0
    return np.exp(-dmin / max(scale, 1e-6))

# -----------------------------
# 10) Candidate generation
# -----------------------------
def sobol_candidates(n, dim, seed=123):
    engine = torch.quasirandom.SobolEngine(dimension=dim, scramble=True, seed=seed)
    return engine.draw(n).cpu().numpy()

def trust_region_candidates(x_center, n, sigma=0.08, seed=123):
    rng = np.random.default_rng(seed)
    X = x_center.reshape(1, -1) + rng.normal(0.0, sigma, size=(n, x_center.size))
    return np.clip(X, 0.0, 1.0)

# -----------------------------
# 11) Propose next point (transparent selection)
# -----------------------------
def propose_next_point(models, X_obs, y_obs,
                       xi_base=0.01,
                       n_sobol=22000, n_local=9000, n_far_frac=0.08,
                       random_seed=123,
                       min_dist=1e-3,
                       local_sigma=0.085,
                       top_k=10,
                       hedge_frac=0.10,
                       hedge_mode="ucb",     # "ucb" or "max_sigma"
                       n_ref=12, alpha=0.7   # xi decay with n (scaling-law intuition)
                       ):
    """
    Decision logic (explicit):
    - MAIN score: qEI * (1 - diversity_penalty)  -> exploit + safe exploration
    - HEDGE (with probability hedge_frac): prioritize uncertain or UCB points
    """

    n = X_obs.shape[0]
    y_best = float(np.max(y_obs))
    y_min = float(np.min(y_obs))
    y_range = max(y_best - y_min, 1e-6)

    x_best_obs = X_obs[int(np.argmax(y_obs))]

    # scaling-law inspired exploration decay with more data (but bounded)
    scale_n = float((n_ref / max(n, 1.0)) ** alpha)
    scale_n = float(np.clip(scale_n, 0.35, 1.25))

    # Candidate sources (to reduce blind spots):
    X_global = sobol_candidates(n_sobol, dim=5, seed=random_seed)
    X_local = trust_region_candidates(x_best_obs, n_local, sigma=local_sigma, seed=random_seed + 7)
    rng = np.random.default_rng(random_seed + 999)
    n_far = max(2000, int(n_far_frac * (n_sobol + n_local)))
    X_far = rng.random(size=(n_far, 5))

    X_cand = np.vstack([X_global, X_local, X_far])
    source_tags = (["sobol"] * len(X_global)) + (["trust_region"] * len(X_local)) + (["far_random"] * len(X_far))
    source_tags = np.array(source_tags)

    # Filter near-duplicates
    dmin_all = pairwise_min_dist(X_cand, X_obs)
    keep = dmin_all >= min_dist
    X_cand = X_cand[keep]
    source_tags = source_tags[keep]
    dmin = dmin_all[keep]

    # Predict
    mu, sigma, preds_members = predict_ensemble(models, X_cand)

    # uncertainty-aware xi:
    # assumption: ensemble sigma correlates with epistemic uncertainty
    sigma_med = float(np.median(sigma))
    conf_scale = 1.0 / (1.0 + sigma_med)  # lower uncertainty -> closer to 1
    effective_xi = float(xi_base * y_range * conf_scale * scale_n)

    # MAIN: robust qEI + diversity penalty
    qei = qei_mc(preds_members, y_best=y_best, xi=effective_xi, n_mc=96, seed=random_seed + 33)
    pen = diversity_penalty_from_dmin(dmin, scale=0.02)
    score_main = qei * (1.0 - 0.35 * pen)

    # HEDGE: explore uncertainty / UCB
    if hedge_mode == "ucb":
        beta = 2.5 + 2.0 * scale_n
        score_hedge = mu + beta * sigma
    else:
        score_hedge = sigma

    # Choose main vs hedge
    rng2 = np.random.default_rng(random_seed + 202)
    do_hedge = (rng2.random() < hedge_frac)

    if do_hedge:
        best_idx = int(np.argmax(score_hedge))
        chosen_mode = "HEDGE"
        chosen_score = float(score_hedge[best_idx])
    else:
        best_idx = int(np.argmax(score_main))
        chosen_mode = "MAIN(qEI)"
        chosen_score = float(score_main[best_idx])

    # shortlist by main score
    top_idx = np.argsort(-score_main)[:top_k]

    # source breakdown (post-filter)
    src_counts = {k: int(np.sum(source_tags == k)) for k in ["sobol", "trust_region", "far_random"]}

    return {
        "x_next": X_cand[best_idx],
        "mu_next": float(mu[best_idx]),
        "sigma_next": float(sigma[best_idx]),
        "qei_next": float(qei[best_idx]),
        "dmin_next": float(dmin[best_idx]),
        "source_next": str(source_tags[best_idx]),
        "chosen_mode": chosen_mode,
        "chosen_score": chosen_score,
        "x_best_obs": x_best_obs,
        "y_best_obs": y_best,
        "effective_xi": float(effective_xi),
        "n_candidates": int(X_cand.shape[0]),
        "source_counts": src_counts,
        "topk": [
            {
                "rank": int(r + 1),
                "x": X_cand[i],
                "mu": float(mu[i]),
                "sigma": float(sigma[i]),
                "qei": float(qei[i]),
                "score": float(score_main[i]),
                "dmin": float(dmin[i]),
                "source": str(source_tags[i]),
            }
            for r, i in enumerate(top_idx)
        ],
        "assumptions": [
            "Locality/smoothness: best region likely near current best -> trust region sampling.",
            "Ensemble std is a usable proxy for epistemic uncertainty -> hedge/UCB uses sigma.",
            "Objective is bounded-input; clamp to [0,1] is valid and does not remove true optimum.",
        ]
    }

# -----------------------------
# 12) Interpretability utilities
# -----------------------------
def local_sensitivity_single_model(model, x_point):
    """
    Gradient-based local sensitivity in *scaled* space.
    We normalise absolute gradient magnitudes to sum to 1.
    """
    model.eval()
    x_scaled = x_scaler.transform(x_point.reshape(1, -1))
    x_t = torch.tensor(x_scaled, dtype=torch.float32, device=device, requires_grad=True)

    y_pred = model(x_t)
    y_pred.backward()

    grads = x_t.grad.detach().cpu().numpy().flatten()
    g = np.abs(grads)
    if g.sum() == 0:
        return np.ones_like(g) / len(g)
    return g / g.sum()

def local_sensitivity_ensemble(models, x_point):
    sens = np.stack([local_sensitivity_single_model(m, x_point) for m in models], axis=0)
    return sens.mean(axis=0), sens.std(axis=0)

def one_at_a_time_probe(models, x_point, delta=0.02):
    """
    Simple interpretability probe:
    - for each dimension, evaluate mu(x +/- delta e_i) with clipping.
    - reports directional effect (approx) around x_point.
    """
    x0 = x_point.copy()
    out = []
    for d in range(x0.size):
        xp = x0.copy(); xp[d] = np.clip(xp[d] + delta, 0.0, 1.0)
        xm = x0.copy(); xm[d] = np.clip(xm[d] - delta, 0.0, 1.0)
        mu_p, _, _ = predict_ensemble(models, xp.reshape(1, -1))
        mu_m, _, _ = predict_ensemble(models, xm.reshape(1, -1))
        out.append({
            "dim": d + 1,
            "x_minus": xm[d],
            "x_plus": xp[d],
            "mu_minus": float(mu_m[0]),
            "mu_plus": float(mu_p[0]),
            "delta_mu": float(mu_p[0] - mu_m[0]),
        })
    return out

# -----------------------------
# 13) Data gap diagnostics (bias / coverage)
# -----------------------------
def dataset_diagnostics(X, y):
    diag = {}
    diag["n_points"] = int(X.shape[0])
    diag["y_best"] = float(np.max(y))
    diag["y_worst"] = float(np.min(y))
    diag["y_mean"] = float(np.mean(y))
    diag["y_std"] = float(np.std(y))

    # per-dimension coverage
    per_dim = []
    for j in range(X.shape[1]):
        xj = X[:, j]
        per_dim.append({
            "dim": j + 1,
            "min": float(np.min(xj)),
            "max": float(np.max(xj)),
            "mean": float(np.mean(xj)),
            "std": float(np.std(xj)),
            "near_0": int(np.sum(xj <= 0.05)),
            "near_1": int(np.sum(xj >= 0.95)),
        })
    diag["per_dim"] = per_dim

    # clustering / coverage proxy via pairwise distances
    if X.shape[0] >= 2:
        diff = X[:, None, :] - X[None, :, :]
        d = np.sqrt(np.sum(diff * diff, axis=2) + 1e-12)
        # ignore diagonal
        d = d[~np.eye(X.shape[0], dtype=bool)]
        diag["pairwise_dist_mean"] = float(np.mean(d))
        diag["pairwise_dist_p10"] = float(np.quantile(d, 0.10))
        diag["pairwise_dist_p50"] = float(np.quantile(d, 0.50))
        diag["pairwise_dist_p90"] = float(np.quantile(d, 0.90))
    else:
        diag["pairwise_dist_mean"] = None

    return diag

# -----------------------------
# 14) Main
# -----------------------------
def main():
    print("\n================ WEEK 10 FUNCTION 6 — TRANSPARENT NEXT DATA POINT (<= 6 DECIMALS) ================\n")

    # ---- Decision/Audit object (single source of truth)
    audit = {
        "seed": RANDOM_SEED,
        "device": str(device),
        "n_raw": int(len(y_raw) + (0 if len(dedup_buckets) == len(y_raw) else 0)),
        "n_after_clamp_dedup": int(X_raw.shape[0]),
        "dedup_groups": int(len(dedup_buckets)),
        "notes": [
            "Objective: maximise y. Data contains duplicates and out-of-bound rows; we clamp to [0,1] and average duplicates.",
            "We use a deep ensemble surrogate to obtain mean + uncertainty; acquisition uses robust qEI + diversity penalty.",
            "We include a hedge mechanism to occasionally sample high-uncertainty/UCB points to reduce over-commitment.",
        ]
    }

    # ---- Dataset diagnostics (bias/gaps)
    diag = dataset_diagnostics(X_raw, y_raw)
    audit["dataset_diagnostics"] = diag

    print("Data after clamp+dedup:", f"n={X_raw.shape[0]} points")
    print("Best observed y:", round(diag["y_best"], 6))

    # ---- Tuning (transparent logs)
    best_cfg, best_cv, sh_logs = tune_hyperparameters_successive_halving(
        X_tensor_all, y_tensor_all, seed=RANDOM_SEED
    )
    audit["tuning"] = {"best_cv_mse_scaled_y": float(best_cv), "best_cfg": asdict(best_cfg), "sh_logs": sh_logs}

    print("\n================ FITTING DEEP ENSEMBLE ================\n")
    ensemble_models = fit_ensemble(best_cfg, X_tensor_all, y_tensor_all, base_seed=RANDOM_SEED)

    # Candidate budget scaling (explicit and logged)
    n = X_raw.shape[0]
    n_sobol = int(np.clip(26000 - 500 * (n - 12), 16000, 26000))
    n_local = int(np.clip(9000 + 300 * (n - 12), 7000, 12000))
    audit["candidate_budget"] = {"n_sobol": n_sobol, "n_local": n_local, "n_far_frac": 0.08}

    details = propose_next_point(
        ensemble_models,
        X_raw,
        y_raw,
        xi_base=best_cfg.xi_base,
        n_sobol=n_sobol,
        n_local=n_local,
        n_far_frac=0.08,
        random_seed=RANDOM_SEED,
        min_dist=1e-3,
        local_sigma=0.085,
        top_k=10,
        hedge_frac=0.10,
        hedge_mode="ucb",
        n_ref=12,
        alpha=0.7
    )

    # final submission value: clip and round to <= 6 decimals
    x_next = np.clip(details["x_next"].astype(float), 0.0, 1.0)
    x_next_6 = np.round(x_next, 6)

    # interpretability
    sens_mu, sens_sd = local_sensitivity_ensemble(ensemble_models, x_next)
    probe = one_at_a_time_probe(ensemble_models, x_next, delta=0.02)

    audit["proposal"] = {
        "x_best_obs": np.round(details["x_best_obs"].astype(float), 6).tolist(),
        "y_best_obs": float(details["y_best_obs"]),
        "x_next": x_next_6.tolist(),
        "mu_next": float(details["mu_next"]),
        "sigma_next": float(details["sigma_next"]),
        "qei_next": float(details["qei_next"]),
        "effective_xi": float(details["effective_xi"]),
        "chosen_mode": details["chosen_mode"],
        "chosen_score": float(details["chosen_score"]),
        "nearest_dist_to_data": float(details["dmin_next"]),
        "candidate_source": details["source_next"],
        "source_counts_after_filter": details["source_counts"],
        "assumptions": details["assumptions"],
    }
    audit["interpretability"] = {
        "local_sensitivity_mean": np.round(sens_mu, 4).tolist(),
        "local_sensitivity_std": np.round(sens_sd, 4).tolist(),
        "oaat_probe_delta": 0.02,
        "oaat_probe": probe,
    }

    # -----------------------------
    # PRINT RESULTS (what you submit)
    # -----------------------------
    print("\n================ NEXT DATA POINT (SUBMIT THIS) — <= 6 DECIMALS ================\n")
    print("x_next =", x_next_6)

    print("\n================ MODEL PREDICTION (SURROGATE) ================\n")
    print("mu(x_next)    =", round(details["mu_next"], 6))
    print("sigma(x_next) =", round(details["sigma_next"], 6))
    print("qEI_MC        =", round(details["qei_next"], 6))

    print("\n================ WHY THIS POINT (TRANSPARENT) ================\n")
    print(f"chosen_mode   = {details['chosen_mode']}")
    print(f"source        = {details['source_next']}")
    print(f"effective_xi  = {details['effective_xi']:.6f}")
    print(f"nearest_dist  = {details['dmin_next']:.6f}  (min distance to existing points)")
    print(f"cand_counts   = {details['source_counts']}  (after distance filter)")

    print("\n================ TOP-10 SHORTLIST (by MAIN score) — 6 DECIMALS ================\n")
    for row in details["topk"]:
        print(
            f"{row['rank']:02d}) x={np.round(row['x'].astype(float), 6)} | "
            f"mu={row['mu']:.6f} | sigma={row['sigma']:.6f} | qEI={row['qei']:.6f} | "
            f"score={row['score']:.6f} | dmin={row['dmin']:.6f} | src={row['source']}"
        )

    print("\n================ LOCAL SENSITIVITY (ENSEMBLE GRADIENTS) ================\n")
    for i, (m, s) in enumerate(zip(sens_mu, sens_sd), 1):
        print(f"Dim {i}: mean={m:.3f} | std={s:.3f}")

    print("\n================ ONE-AT-A-TIME PROBE (delta=0.02) ================\n")
    for row in probe:
        print(f"Dim {row['dim']}: mu(+)= {row['mu_plus']:.6f} | mu(-)= {row['mu_minus']:.6f} | delta_mu= {row['delta_mu']:.6f}")

    print("\n================ DATASET GAPS / BIASES (DIAGNOSTICS) ================\n")
    print(f"n_points={diag['n_points']} | y_best={diag['y_best']:.6f} | y_mean={diag['y_mean']:.6f} | y_std={diag['y_std']:.6f}")
    print("Pairwise distances:",
          f"mean={diag.get('pairwise_dist_mean', None)}",
          f"p10={diag.get('pairwise_dist_p10', None)}",
          f"p50={diag.get('pairwise_dist_p50', None)}",
          f"p90={diag.get('pairwise_dist_p90', None)}")
    for d in diag["per_dim"]:
        print(f"Dim {d['dim']}: min={d['min']:.3f} max={d['max']:.3f} mean={d['mean']:.3f} std={d['std']:.3f} near0={d['near_0']} near1={d['near_1']}")

    print("\n================ KEY ASSUMPTIONS (EXPLICIT) ================\n")
    for a in details["assumptions"]:
        print("-", a)

    # If you want a machine-readable record, you can uncomment:
    # import json
    # print("\nAUDIT_JSON=\n", json.dumps(audit, indent=2))

if __name__ == "__main__":
    main()
# Out:
# ================ WEEK 10 FUNCTION 6 — TRANSPARENT NEXT DATA POINT (<= 6 DECIMALS) ================
#
# Data after clamp+dedup: n=28 points
# Best observed y: -0.293185
# [SH stage 1] cfg 01/18 | CV-MSE=0.317757 | {'hidden_layers': (64, 64), 'dropout': 0.1, 'lr': 0.00045277351007438286, 'weight_decay': 5.837380423441397e-07, 'use_layernorm': True, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 1] cfg 02/18 | CV-MSE=0.108928 | {'hidden_layers': (64, 64), 'dropout': 0.03, 'lr': 0.003352779476383228, 'weight_decay': 9.15551370547805e-07, 'use_layernorm': False, 'n_ensemble': 7, 'xi_base': 0.02}
# [SH stage 1] cfg 03/18 | CV-MSE=0.299569 | {'hidden_layers': (256, 128), 'dropout': 0.16, 'lr': 0.0013032581411905396, 'weight_decay': 7.108396118035575e-07, 'use_layernorm': True, 'n_ensemble': 7, 'xi_base': 0.02}
# [SH stage 1] cfg 04/18 | CV-MSE=0.142884 | {'hidden_layers': (64, 64), 'dropout': 0.06, 'lr': 0.0017060831586461437, 'weight_decay': 0.00016776736768971655, 'use_layernorm': False, 'n_ensemble': 7, 'xi_base': 0.0}
# [SH stage 1] cfg 05/18 | CV-MSE=0.293279 | {'hidden_layers': (256, 128), 'dropout': 0.1, 'lr': 0.0013189399657074516, 'weight_decay': 6.384795396961156e-07, 'use_layernorm': True, 'n_ensemble': 5, 'xi_base': 0.0}
# [SH stage 1] cfg 06/18 | CV-MSE=0.150383 | {'hidden_layers': (128, 64), 'dropout': 0.0, 'lr': 0.0006115021365273104, 'weight_decay': 1.1266562536616612e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 1] cfg 07/18 | CV-MSE=0.141756 | {'hidden_layers': (64, 64), 'dropout': 0.1, 'lr': 0.003316350949615086, 'weight_decay': 1.4964340681826228e-05, 'use_layernorm': False, 'n_ensemble': 7, 'xi_base': 0.01}
# [SH stage 1] cfg 08/18 | CV-MSE=0.360212 | {'hidden_layers': (256, 128), 'dropout': 0.06, 'lr': 0.0029389176837015677, 'weight_decay': 3.474666201818485e-05, 'use_layernorm': True, 'n_ensemble': 7, 'xi_base': 0.005}
# [SH stage 1] cfg 09/18 | CV-MSE=0.142419 | {'hidden_layers': (128, 64), 'dropout': 0.1, 'lr': 0.0029327949794944433, 'weight_decay': 1.099466171269843e-06, 'use_layernorm': False, 'n_ensemble': 7, 'xi_base': 0.01}
# [SH stage 1] cfg 10/18 | CV-MSE=0.152543 | {'hidden_layers': (64, 64), 'dropout': 0.03, 'lr': 0.0006917774337966829, 'weight_decay': 4.569528106521275e-05, 'use_layernorm': False, 'n_ensemble': 7, 'xi_base': 0.0}
# [SH stage 1] cfg 11/18 | CV-MSE=0.404931 | {'hidden_layers': (128, 128), 'dropout': 0.03, 'lr': 0.0004135561352482403, 'weight_decay': 1.297737870883513e-07, 'use_layernorm': True, 'n_ensemble': 5, 'xi_base': 0.01}
# [SH stage 1] cfg 12/18 | CV-MSE=0.372860 | {'hidden_layers': (128, 64), 'dropout': 0.16, 'lr': 0.0007238065289205709, 'weight_decay': 1.025796239733974e-07, 'use_layernorm': True, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 1] cfg 13/18 | CV-MSE=0.278697 | {'hidden_layers': (128, 128), 'dropout': 0.06, 'lr': 0.0010699383704841474, 'weight_decay': 8.012206274545792e-05, 'use_layernorm': True, 'n_ensemble': 7, 'xi_base': 0.0}
# [SH stage 1] cfg 14/18 | CV-MSE=0.176059 | {'hidden_layers': (128, 64), 'dropout': 0.06, 'lr': 0.0012634170737524286, 'weight_decay': 4.3498621637118784e-05, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.01}
# [SH stage 1] cfg 15/18 | CV-MSE=0.127431 | {'hidden_layers': (256, 128), 'dropout': 0.06, 'lr': 0.0009958970266546463, 'weight_decay': 1.1948538636335782e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 1] cfg 16/18 | CV-MSE=0.128482 | {'hidden_layers': (128, 128), 'dropout': 0.06, 'lr': 0.0010898985417074698, 'weight_decay': 4.882407733169447e-06, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.01}
# [SH stage 1] cfg 17/18 | CV-MSE=0.105031 | {'hidden_layers': (128, 128), 'dropout': 0.06, 'lr': 0.0015165464269857258, 'weight_decay': 1.7563773235675597e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 1] cfg 18/18 | CV-MSE=0.135283 | {'hidden_layers': (128, 128), 'dropout': 0.0, 'lr': 0.00107619336890803, 'weight_decay': 1.129483085778142e-06, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.0}
#
# [SH stage 1] best so far: 0.105031 | {'hidden_layers': (128, 128), 'dropout': 0.06, 'lr': 0.0015165464269857258, 'weight_decay': 1.7563773235675597e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
#
# [SH stage 2] cfg 01/6 | CV-MSE=0.124333 | {'hidden_layers': (128, 128), 'dropout': 0.06, 'lr': 0.0015165464269857258, 'weight_decay': 1.7563773235675597e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 2] cfg 02/6 | CV-MSE=0.214751 | {'hidden_layers': (64, 64), 'dropout': 0.03, 'lr': 0.003352779476383228, 'weight_decay': 9.15551370547805e-07, 'use_layernorm': False, 'n_ensemble': 7, 'xi_base': 0.02}
# [SH stage 2] cfg 03/6 | CV-MSE=0.120904 | {'hidden_layers': (256, 128), 'dropout': 0.06, 'lr': 0.0009958970266546463, 'weight_decay': 1.1948538636335782e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 2] cfg 04/6 | CV-MSE=0.131837 | {'hidden_layers': (128, 128), 'dropout': 0.06, 'lr': 0.0010898985417074698, 'weight_decay': 4.882407733169447e-06, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.01}
# [SH stage 2] cfg 05/6 | CV-MSE=0.124460 | {'hidden_layers': (128, 128), 'dropout': 0.0, 'lr': 0.00107619336890803, 'weight_decay': 1.129483085778142e-06, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.0}
# [SH stage 2] cfg 06/6 | CV-MSE=0.199624 | {'hidden_layers': (64, 64), 'dropout': 0.1, 'lr': 0.003316350949615086, 'weight_decay': 1.4964340681826228e-05, 'use_layernorm': False, 'n_ensemble': 7, 'xi_base': 0.01}
#
# [SH stage 2] best so far: 0.120904 | {'hidden_layers': (256, 128), 'dropout': 0.06, 'lr': 0.0009958970266546463, 'weight_decay': 1.1948538636335782e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
#
# [SH stage 3] cfg 01/2 | CV-MSE=0.079510 | {'hidden_layers': (256, 128), 'dropout': 0.06, 'lr': 0.0009958970266546463, 'weight_decay': 1.1948538636335782e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
# [SH stage 3] cfg 02/2 | CV-MSE=0.083400 | {'hidden_layers': (128, 128), 'dropout': 0.06, 'lr': 0.0015165464269857258, 'weight_decay': 1.7563773235675597e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
#
# [SH stage 3] best so far: 0.079510 | {'hidden_layers': (256, 128), 'dropout': 0.06, 'lr': 0.0009958970266546463, 'weight_decay': 1.1948538636335782e-07, 'use_layernorm': False, 'n_ensemble': 5, 'xi_base': 0.005}
#
#
# ================ FITTING DEEP ENSEMBLE ================
#
#
# ================ NEXT DATA POINT (SUBMIT THIS) — <= 6 DECIMALS ================
#
# x_next = [0.019634 0.099529 0.422099 0.998212 0.080632]
#
# ================ MODEL PREDICTION (SURROGATE) ================
#
# mu(x_next)    = -0.814397
# sigma(x_next) = 0.506952
# qEI_MC        = 0.109536
#
# ================ WHY THIS POINT (TRANSPARENT) ================
#
# chosen_mode   = MAIN(qEI)
# source        = far_random
# effective_xi  = 0.006295
# nearest_dist  = 0.314275  (min distance to existing points)
# cand_counts   = {'sobol': 18000, 'trust_region': 12000, 'far_random': 2400}  (after distance filter)
#
# ================ TOP-10 SHORTLIST (by MAIN score) — 6 DECIMALS ================
#
# 01) x=[0.019634 0.099529 0.422099 0.998212 0.080632] | mu=-0.814397 | sigma=0.506952 | qEI=0.109536 | score=0.109536 | dmin=0.314275 | src=far_random
# 02) x=[0.026438 0.104894 0.463667 0.99637  0.032395] | mu=-0.721894 | sigma=0.483983 | qEI=0.109424 | score=0.109424 | dmin=0.295310 | src=sobol
# 03) x=[0.179504 0.089909 0.69421  0.932404 0.01356 ] | mu=-0.464844 | sigma=0.278542 | qEI=0.095026 | score=0.095025 | dmin=0.245168 | src=trust_region
# 04) x=[0.218698 0.054827 0.721572 0.950176 0.      ] | mu=-0.450611 | sigma=0.289737 | qEI=0.094037 | score=0.094036 | dmin=0.222071 | src=trust_region
# 05) x=[0.337576 0.048408 0.655485 0.985804 0.      ] | mu=-0.447251 | sigma=0.282475 | qEI=0.090065 | score=0.090065 | dmin=0.272570 | src=trust_region
# 06) x=[0.137149 0.038261 0.515808 0.87471  0.048889] | mu=-0.682462 | sigma=0.374735 | qEI=0.087221 | score=0.087221 | dmin=0.291409 | src=sobol
# 07) x=[0.137382 0.16801  0.664116 0.974944 0.025665] | mu=-0.458446 | sigma=0.276485 | qEI=0.086273 | score=0.086272 | dmin=0.236781 | src=trust_region
# 08) x=[0.249763 0.087062 0.665726 0.940694 0.      ] | mu=-0.430639 | sigma=0.254031 | qEI=0.085014 | score=0.085014 | dmin=0.245397 | src=trust_region
# 09) x=[0.082271 0.021484 0.080556 0.993436 0.155424] | mu=-1.252805 | sigma=0.667090 | qEI=0.082013 | score=0.081988 | dmin=0.140948 | src=sobol
# 10) x=[0.26597  0.113498 0.586967 0.962433 0.      ] | mu=-0.438290 | sigma=0.267946 | qEI=0.081677 | score=0.081674 | dmin=0.181933 | src=trust_region
#
# ================ LOCAL SENSITIVITY (ENSEMBLE GRADIENTS) ================
#
# Dim 1: mean=0.205 | std=0.089
# Dim 2: mean=0.205 | std=0.050
# Dim 3: mean=0.175 | std=0.093
# Dim 4: mean=0.196 | std=0.081
# Dim 5: mean=0.220 | std=0.093
#
# ================ ONE-AT-A-TIME PROBE (delta=0.02) ================
#
# Dim 1: mu(+)= -0.796007 | mu(-)= -0.833100 | delta_mu= 0.037094
# Dim 2: mu(+)= -0.800335 | mu(-)= -0.829063 | delta_mu= 0.028728
# Dim 3: mu(+)= -0.796826 | mu(-)= -0.832658 | delta_mu= 0.035832
# Dim 4: mu(+)= -0.814159 | mu(-)= -0.817363 | delta_mu= 0.003204
# Dim 5: mu(+)= -0.833326 | mu(-)= -0.795607 | delta_mu= -0.037718
#
# ================ DATASET GAPS / BIASES (DIAGNOSTICS) ================
#
# n_points=28 | y_best=-0.293185 | y_mean=-1.418196 | y_std=0.629598
# Pairwise distances: mean=0.9479415475671009 p10=0.5675956092976611 p50=0.9425377442811714 p90=1.3420991306595502
# Dim 1: min=0.022 max=1.000 mean=0.521 std=0.308 near0=1 near1=3
# Dim 2: min=0.014 max=1.000 mean=0.513 std=0.306 near0=1 near1=1
# Dim 3: min=0.017 max=1.000 mean=0.518 std=0.308 near0=3 near1=3
# Dim 4: min=0.046 max=1.000 mean=0.623 std=0.287 near0=1 near1=6
# Dim 5: min=0.000 max=0.993 mean=0.386 std=0.331 near0=6 near1=1
#
# ================ KEY ASSUMPTIONS (EXPLICIT) ================
#
# - Locality/smoothness: best region likely near current best -> trust region sampling.
# - Ensemble std is a usable proxy for epistemic uncertainty -> hedge/UCB uses sigma.
# - Objective is bounded-input; clamp to [0,1] is valid and does not remove true optimum.
